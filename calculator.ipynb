# %%
def add():
  print("add")
def sub():
  print("sub")
def mul():
  print("mul")
def div():
  print("div")

num1=float(input("enter the number:"))
num2=float(input("enter the number:"))

add()
print("addition:",num1+num2)
sub()
print("subtraction:",num1-num2)
mul()
print("multiplication:",num1*num2)
div()
if num2 !=0:
      print("division:",num1/num2)
else:
      print("cannot divide by zero")
# Out:
# enter the number:17
# enter the number:77
# add
# addition: 94.0
# sub
# subtraction: -60.0
# mul
# multiplication: 1309.0
# div
# division: 0.22077922077922077
